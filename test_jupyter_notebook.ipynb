# %% [markdown]
# # Title "# Title"

# %% [markdown]
# *Bold* _italic_

# %%
print("Hello World! " + "Tercio!")
name : str = "Tercio"
type(name)
# Out:
# Hello World! Tercio!
# str

# %%
x = 5
print(x)
# Out:
# 5

# %%
type(1j * 1j) # Complex numbers
# Out:
# complex

# %%
my_list = [1, 2, 3, 4]
print(my_list)
len(my_list)
type(my_list)
# Out:
# [1, 2, 3, 4]
# list

# %%
my_set = { 5, 4, 3, 2 ,1 }
print(my_set)
len(my_set)
type(my_set)
my_set_2 = my_set
my_set_2 = { 2, 2, 3, 3, 4 }
print(my_set_2)
print(my_set)
# Out:
# {1, 2, 3, 4, 5}
# {2, 3, 4}
# {1, 2, 3, 4, 5}

# %%
my_tuple = (1,2,3)
my_tuple == (3,2,1)
print(my_tuple)
print("Tuples cant be modified")
# Out:
# (1, 2, 3)
# Tuples cant be modified
